# %%
1. Input the names, ages, heights and scores of the girls and boys 
2. Merge the lists using concatenation
3. Make the headers(columns) using using strings
4. Iterate through the list for each index, making values align under correct headers
5. Print tht final table formatted
