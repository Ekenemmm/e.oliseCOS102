# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(Users/EKENEM/Documents/e.oliseCOS102/week4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv(Users/EKENEM/Documents/e.oliseCOS102/week4)
#
# NameError: name 'Users' is not defined
